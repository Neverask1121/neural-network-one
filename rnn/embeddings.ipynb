# %%
## import all the libraries

from tensorflow.keras.preprocessing.text import one_hot

# %%
## saample sentences

sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## defining the vocabulory size

voc_size = 10000

# %%
## One Hot Representation for each of the words

one_hot_rep = [one_hot(words, voc_size)for words in sent]
one_hot_rep
# Out:
# [[5484, 5139, 9497, 3379],
#  [5484, 5139, 9497, 7774],
#  [5484, 3896, 9497, 5854],
#  [3260, 9767, 8905, 9152, 6781],
#  [3260, 9767, 8905, 9152, 1391],
#  [3668, 5484, 3110, 9497, 4215],
#  [5270, 1152, 1361, 9152]]

# %%
## Word Embedding representation

from tensorflow.keras.layers import Input, Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential
import numpy as np

# %%
## Providing padding to each array of sentences

sent_length = 8
embedded_docs = pad_sequences(one_hot_rep, padding = 'pre', maxlen = sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 5484 5139 9497 3379]
#  [   0    0    0    0 5484 5139 9497 7774]
#  [   0    0    0    0 5484 3896 9497 5854]
#  [   0    0    0 3260 9767 8905 9152 6781]
#  [   0    0    0 3260 9767 8905 9152 1391]
#  [   0    0    0 3668 5484 3110 9497 4215]
#  [   0    0    0    0 5270 1152 1361 9152]]

# %%
## feature representation

dim = 10

# %%
model = Sequential([
    Input(shape=(sent_length,)),
    Embedding(voc_size, dim)
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 8, 10)          │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# array([[[-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [ 0.01434353, -0.03661213,  0.02961374, -0.01379185,
#          -0.04967619, -0.03757306, -0.02991557, -0.04438061,
#           0.0069545 , -0.02942905],
#         [ 0.03166649, -0.04906646,  0.00707684, -0.04172271,
#           0.03019693,  0.03490552,  0.00463393, -0.02586991,
#          -0.04206481, -0.0396795 ],
#         [ 0.02189603,  0.00173686,  0.03951547,  0.01843398,
#           0.04552804, -0.02282702, -0.00232445,  0.0055109 ,
#           0.03610111, -0.03068421],
#         [-0.03470628, -0.03525979,  0.03856461, -0.04204828,
#          -0.03987711,  0.01313284, -0.03024842, -0.01576207,
#           0.00338204,  0.01767593]],
#
#        [[-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [ 0.01434353, -0.03661213,  0.02961374, -0.01379185,
#          -0.04967619, -0.03757306, -0.02991557, -0.04438061,
#           0.0069545 , -0.02942905],
#         [ 0.03166649, -0.04906646,  0.00707684, -0.04172271,
#           0.03019693,  0.03490552,  0.00463393, -0.02586991,
#          -0.04206481, -0.0396795 ],
#         [ 0.02189603,  0.00173686,  0.03951547,  0.01843398,
#           0.04552804, -0.02282702, -0.00232445,  0.0055109 ,
#           0.03610111, -0.03068421],
#         [-0.02987353, -0.02297433,  0.02897752,  0.00101291,
#          -0.00227467,  0.02739723, -0.01001712, -0.04222953,
#          -0.04471551, -0.00910044]],
#
#        [[-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [ 0.01434353, -0.03661213,  0.02961374, -0.01379185,
#          -0.04967619, -0.03757306, -0.02991557, -0.04438061,
#           0.0069545 , -0.02942905],
#         [ 0.03688308, -0.03958589,  0.00333653, -0.00044216,
#           0.04831618, -0.03440129, -0.04960818, -0.01320391,
#           0.00545619,  0.03537044],
#         [ 0.02189603,  0.00173686,  0.03951547,  0.01843398,
#           0.04552804, -0.02282702, -0.00232445,  0.0055109 ,
#           0.03610111, -0.03068421],
#         [ 0.0385303 ,  0.03901051,  0.00411282,  0.00962334,
#           0.03280209,  0.03847114, -0.0379397 , -0.04358577,
#           0.0060012 , -0.02989455]],
#
#        [[-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [ 0.00159488, -0.03166677,  0.03522008,  0.03325211,
#           0.00808822,  0.00822914, -0.03097017, -0.02319994,
#           0.03984768,  0.02838123],
#         [ 0.02493582, -0.01930075,  0.02265492,  0.01315973,
#          -0.01530718, -0.04652242, -0.02095001, -0.02871611,
#           0.01440475,  0.01391366],
#         [-0.04030273, -0.03329666,  0.00856193, -0.03888321,
#           0.00766188, -0.0298439 ,  0.03200654, -0.00885794,
#          -0.04135358,  0.01976626],
#         [-0.03311311,  0.01762855, -0.03313993,  0.00902153,
#          -0.04635899,  0.03128408,  0.04402548, -0.03407329,
#           0.02047154,  0.03781041],
#         [-0.00118563, -0.01831559,  0.00579708,  0.01892883,
#           0.00633947,  0.03271599,  0.03371234,  0.00940844,
#          -0.01996197, -0.00767788]],
#
#        [[-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [ 0.00159488, -0.03166677,  0.03522008,  0.03325211,
#           0.00808822,  0.00822914, -0.03097017, -0.02319994,
#           0.03984768,  0.02838123],
#         [ 0.02493582, -0.01930075,  0.02265492,  0.01315973,
#          -0.01530718, -0.04652242, -0.02095001, -0.02871611,
#           0.01440475,  0.01391366],
#         [-0.04030273, -0.03329666,  0.00856193, -0.03888321,
#           0.00766188, -0.0298439 ,  0.03200654, -0.00885794,
#          -0.04135358,  0.01976626],
#         [-0.03311311,  0.01762855, -0.03313993,  0.00902153,
#          -0.04635899,  0.03128408,  0.04402548, -0.03407329,
#           0.02047154,  0.03781041],
#         [ 0.02615448, -0.01704043,  0.02015305,  0.00582965,
#           0.00061716,  0.01330538, -0.04394273,  0.02938011,
#          -0.00551953, -0.0148109 ]],
#
#        [[-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03869367,  0.0388161 , -0.03334869, -0.03310807,
#           0.03753698,  0.00080042,  0.00034305, -0.00789056,
#          -0.02186959,  0.03788565],
#         [ 0.01434353, -0.03661213,  0.02961374, -0.01379185,
#          -0.04967619, -0.03757306, -0.02991557, -0.04438061,
#           0.0069545 , -0.02942905],
#         [ 0.00319611,  0.03817293,  0.04147753,  0.04364907,
#          -0.02004757,  0.01435554,  0.04521007, -0.01114348,
#          -0.03994638, -0.00215684],
#         [ 0.02189603,  0.00173686,  0.03951547,  0.01843398,
#           0.04552804, -0.02282702, -0.00232445,  0.0055109 ,
#           0.03610111, -0.03068421],
#         [-0.02241329,  0.0040557 ,  0.03736684, -0.01021574,
#           0.03216868,  0.04936336,  0.01519949,  0.03995213,
#           0.03456217,  0.0497708 ]],
#
#        [[-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.00134512,  0.00219814, -0.00731342, -0.03473389,
#          -0.04227014, -0.02460434, -0.02739021,  0.04414041,
#           0.01647698, -0.04183518],
#         [-0.00970481,  0.03206574,  0.01661862,  0.03506979,
#          -0.0001598 , -0.01249563, -0.00727392,  0.02267705,
#           0.01373649,  0.01951956],
#         [-0.00626284, -0.01766313,  0.04112611,  0.02191094,
#           0.01628144, -0.00770366, -0.03791109, -0.02939738,
#          -0.03587591, -0.02720002],
#         [-0.03311311,  0.01762855, -0.03313993,  0.00902153,
#          -0.04635899,  0.03128408,  0.04402548, -0.03407329,
#           0.02047154,  0.03781041]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 5484, 5139, 9497, 3379], dtype=int32)

# %%
import tensorflow as tf
import keras
import numpy as np

print("TensorFlow:", tf.__version__)
print("Keras:", keras.__version__)
print("NumPy:", np.__version__)

print(type(embedded_docs))
print(embedded_docs.shape)
print(type(embedded_docs[0]))
print(embedded_docs[0].shape)
# Out:
# TensorFlow: 2.21.0
# Keras: 3.15.0
# NumPy: 2.4.6
# <class 'numpy.ndarray'>
# (7, 8)
# <class 'numpy.ndarray'>
# (8,)

# %%
model.predict(np.expand_dims(embedded_docs[0], axis=0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# array([[[-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [-0.03639759,  0.02525708,  0.01419164, -0.02741921,
#           0.04431525,  0.0170351 ,  0.02119699,  0.03654763,
#           0.04899812,  0.04597746],
#         [ 0.01434353, -0.03661213,  0.02961374, -0.01379185,
#          -0.04967619, -0.03757306, -0.02991557, -0.04438061,
#           0.0069545 , -0.02942905],
#         [ 0.03166649, -0.04906646,  0.00707684, -0.04172271,
#           0.03019693,  0.03490552,  0.00463393, -0.02586991,
#          -0.04206481, -0.0396795 ],
#         [ 0.02189603,  0.00173686,  0.03951547,  0.01843398,
#           0.04552804, -0.02282702, -0.00232445,  0.0055109 ,
#           0.03610111, -0.03068421],
#         [-0.03470628, -0.03525979,  0.03856461, -0.04204828,
#          -0.03987711,  0.01313284, -0.03024842, -0.01576207,
#           0.00338204,  0.01767593]]], dtype=float32)
